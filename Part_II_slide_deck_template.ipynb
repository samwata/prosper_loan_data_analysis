# %% [markdown]
# # Part II - Propser Loan Data
# ## by Samson Amwata

# %% [markdown]
# ## Investigation Overview
#
#
# I focused on key features that will answer the questions for my investigation. I started by showing the amount of loan loaned out and to find out if the Borrower Rate, Prosper rating and APR rate has effect on the amount of loan borrowed. Also I checked the correlation between different features
#
#
# ## Dataset Overview
#
# This dataset contains loan information of about 113,937 rows with 81 variables on each loan, including loan amount, borrower rate (or interest rate), current loan status, borrower income, and many others.
#
# I am looking forward to investigate the following questions
#
# - What factors affect a loan’s outcome status?
# - What affects the borrower’s APR or interest rate?
# - Are there differences between loans depending on how large the original loan amount was?

# %%
# import all packages and set plots to be embedded inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %matplotlib inline

# suppress warnings from final output
import warnings
warnings.simplefilter("ignore")

# %%
# load in the dataset into a pandas dataframe
df = pd.read_csv("prosperLoanData.csv")

# %% [markdown]
# ### Borrowers Rate Vs Period
# The distribution of Borrower rate and Borrower APR looks multimodal. There is a peak centered at 0.2 and there is a very high increase between 0.35 and 0.36.
# The borrowers in 2011 got the highest interest rate compared to borrowers in 2005 who got the lowest interest rate

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Income Range Vs Borrower Rate
# We can see that borrowers rate has negative correlation with Income range where the Borrowers rate reduces with increased income rate. This means that the borrowers with high income range is having a lower interest rate which I think it is sales technique to allow high income earners to borrow more

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Loan Amount Vs Period
#
# We found that the amount of loans borrowered by year dropped off in 2009 and there was high number of loan amount in 2013 and increased steadily after 2009. The loan amount taken in 2013 might be affected by either inflation or other economic factors

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Borrower rate Vs HomeOwner over time
# I wanted to check the relationship between Interest rate among borrowers with home and those without. I notice that the homeowners got lower interest rate in general throughout the years. We also have outliers on 2005 2006 2007 2008 and 2014. we might consider removing them if we decide to do predictive analysis

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# !jupyter nbconvert Part_II_slide_deck_template.ipynb --to slides --post serve --no-input --no-prompt
# Out:
# [NbConvertApp] WARNING | Config option `kernel_spec_manager_class` not recognized by `NbConvertApp`.
# [NbConvertApp] Converting notebook Part_II_slide_deck_template.ipynb to slides
# [NbConvertApp] Writing 381504 bytes to Part_II_slide_deck_template.slides.html
# [NbConvertApp] Redirecting reveal.js requests to https://cdnjs.cloudflare.com/ajax/libs/reveal.js/3.5.0
# Traceback (most recent call last):
#   File "C:\Users\samso\Anaconda3\envs\altx_data\Scripts\jupyter-nbconvert-script.py", line 9, in <module>
#     sys.exit(main())
#   File "C:\Users\samso\Anaconda3\envs\altx_data\lib\site-packages\jupyter_core\application.py", line 269, in launch_instance
#     return super().launch_instance(argv=argv, **kwargs)
#   File "C:\Users\samso\Anaconda3\envs\altx_data\lib\site-packages\traitlets\config\application.py", line 846, in launch_instance
#     app.start()
#   File "C:\Users\samso\Anaconda3\envs\altx_data\lib\site-packages\nbconvert\nbconvertapp.py", line 338, in start
# ...

# %% [markdown]
# > This should open a tab in your web browser where you can scroll through your presentation. Sub-slides can be accessed by pressing 'down' when viewing its parent slide. Make sure you remove all of the quote-formatted guide notes like this one before you finish your presentation! At last, you can stop the Kernel.
